# %% [markdown]
# # Membaca Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dshouse = pd.read_csv('house.csv')

# %%
dshouse
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0              1360             2              1        1981  0.599637
# 1              4272             3              3        2016  4.753014
# 2              3592             1              2        2016  3.634823
# 3               966             1              2        1977  2.730667
# 4              4926             2              1        1993  4.699073
# ..              ...           ...            ...         ...       ...
# 995            3261             4              1        1978  2.165110
# 996            3179             1              2        1999  2.977123
# 997            2606             4              2        1962  4.055067
# 998            4723             5              2        1950  1.930921
# 999            3268             4              2        1983  3.108790
#
#      Garage_Size  Neighborhood_Quality   House_Price
# 0              0                     5  2.623829e+05
# 1              1                     6  9.852609e+05
# 2              0                     9  7.779774e+05
# 3              1                     8  2.296989e+05
# 4              0                     8  1.041741e+06
# ..           ...                   ...           ...
# 995            2                    10  7.014940e+05
# 996            1                    10  6.837232e+05
# 997            0                     2  5.720240e+05
# 998            0                     7  9.648653e+05
# 999            2                     2  7.425993e+05
#
# [1000 rows x 8 columns]

# %%
dshouse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Square_Footage        1000 non-null   int64
#  1   Num_Bedrooms          1000 non-null   int64
#  2   Num_Bathrooms         1000 non-null   int64
#  3   Year_Built            1000 non-null   int64
#  4   Lot_Size              1000 non-null   float64
#  5   Garage_Size           1000 non-null   int64
#  6   Neighborhood_Quality  1000 non-null   int64
#  7   House_Price           1000 non-null   float64
# dtypes: float64(2), int64(6)
# memory usage: 62.6 KB

# %%
x = dshouse.drop(columns=['House_Price'])
y = dshouse['House_Price']

# %%
x
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0              1360             2              1        1981  0.599637
# 1              4272             3              3        2016  4.753014
# 2              3592             1              2        2016  3.634823
# 3               966             1              2        1977  2.730667
# 4              4926             2              1        1993  4.699073
# ..              ...           ...            ...         ...       ...
# 995            3261             4              1        1978  2.165110
# 996            3179             1              2        1999  2.977123
# 997            2606             4              2        1962  4.055067
# 998            4723             5              2        1950  1.930921
# 999            3268             4              2        1983  3.108790
#
#      Garage_Size  Neighborhood_Quality
# 0              0                     5
# 1              1                     6
# 2              0                     9
# 3              1                     8
# 4              0                     8
# ..           ...                   ...
# 995            2                    10
# 996            1                    10
# 997            0                     2
# 998            0                     7
# 999            2                     2
#
# [1000 rows x 7 columns]

# %%
y
# Out:
# 0      2.623829e+05
# 1      9.852609e+05
# 2      7.779774e+05
# 3      2.296989e+05
# 4      1.041741e+06
#            ...
# 995    7.014940e+05
# 996    6.837232e+05
# 997    5.720240e+05
# 998    9.648653e+05
# 999    7.425993e+05
# Name: House_Price, Length: 1000, dtype: float64

# %% [markdown]
# # Split train test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=42)

# %%
x_test
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 521            4012             3              1        2016  2.098092
# 737            2310             3              1        1988  1.369622
# 740            4708             1              3        1962  1.792970
# 660            4932             2              1        1972  4.479598
# 411            3646             1              1        1994  3.980987
# ..              ...           ...            ...         ...       ...
# 56             3113             5              2        1999  3.781556
# 405             614             2              3        1956  3.933020
# 442            2319             2              2        1998  0.893969
# 757            2119             2              1        2007  2.334721
# 997            2606             4              2        1962  4.055067
#
#      Garage_Size  Neighborhood_Quality
# 521            1                     5
# 737            1                     4
# 740            1                     8
# 660            1                     2
# 411            0                     9
# ..           ...                   ...
# 56             1                     2
# 405            0                     9
# 442            0                     1
# 757            0                     4
# 997            0                     2
#
# [400 rows x 7 columns]

# %%
y_test
# Out:
# 521    9.010005e+05
# 737    4.945375e+05
# 740    9.494042e+05
# 660    1.040389e+06
# 411    7.940100e+05
#            ...
# 56     7.313317e+05
# 405    1.725344e+05
# 442    5.017207e+05
# 757    4.682514e+05
# 997    5.720240e+05
# Name: House_Price, Length: 400, dtype: float64

# %%
x_train
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 24              689             5              1        1996  3.886872
# 467            3493             1              1        2011  1.140149
# 539            4685             5              2        2017  0.914756
# 531            1853             2              3        2020  3.022609
# 618            3972             3              2        2018  2.920023
# ..              ...           ...            ...         ...       ...
# 106            2257             5              1        1968  3.131006
# 270            3894             3              2        1975  1.256532
# 860            1484             5              1        2010  1.246555
# 435            1865             4              2        1994  4.354220
# 102            1363             4              1        1977  4.408878
#
#      Garage_Size  Neighborhood_Quality
# 24             2                     2
# 467            2                     9
# 539            2                     1
# 531            2                     8
# 618            0                     5
# ..           ...                   ...
# 106            0                     2
# 270            0                     5
# 860            1                     6
# 435            0                     7
# 102            1                     1
#
# [600 rows x 7 columns]

# %%
y_train
# Out:
# 24     2.275153e+05
# 467    7.244205e+05
# 539    1.015604e+06
# 531    4.718169e+05
# 618    8.780493e+05
#            ...
# 106    5.013055e+05
# 270    7.970344e+05
# 860    3.603730e+05
# 435    4.785661e+05
# 102    3.400692e+05
# Name: House_Price, Length: 600, dtype: float64

# %% [markdown]
# # Membuat model regresi linear dan melatihnya

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Visualisasi Data

# %%
plt.figure(figsize=(12, 8))
sns.regplot(x=x_train['Square_Footage'], y=y_train, line_kws={"color": "magenta"})
plt.title("Square Footage vs. House Price")
plt.xlabel("Square Footage")
plt.ylabel("House Price")
plt.show()

# %% [markdown]
# # Evaluasi model pada data uji

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# # Membuat 10 data baru tanpa label

# %%
data_baru = pd.DataFrame({
    'Square_Footage': np.random.randint(500, 5000, 10),
    'Num_Bedrooms': np.random.randint(1, 5, 10),
    'Num_Bathrooms': np.random.randint(1, 4, 10),
    'Year_Built': np.random.randint(1950, 2023, 10),
    'Lot_Size': np.random.uniform(0.1, 5.0, 10),
    'Garage_Size': np.random.randint(0, 3, 10),
    'Neighborhood_Quality': np.random.randint(1, 10, 10)
})

# %%
print(data_baru)
# Out:
#    Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0            3938             3              2        1958  3.913819
# 1            2010             2              3        2003  2.767976
# 2            1934             4              2        1973  0.847470
# 3            4170             1              3        2006  1.069368
# 4             668             2              2        1964  1.147526
# 5            3952             2              3        1999  4.621789
# 6            1089             3              1        2012  3.083953
# 7            3973             1              1        1997  2.802667
# 8            3195             2              1        2022  1.074873
# 9            3934             3              1        1957  1.469066
#
#    Garage_Size  Neighborhood_Quality
# 0            2                     4
# 1            0                     8
# 2            0                     8
# 3            0                     5
# 4            0                     9
# 5            2                     3
# 6            0                     3
# 7            1                     4
# 8            0                     2
# 9            1                     7

# %% [markdown]
# # Melakukan prediksi pada data baru

# %%
prediksi = model.predict(data_baru)
print("Data baru untuk prediksi:\n", data_baru)
print("Hasil prediksi:\n", prediksi)
# Out:
# Data baru untuk prediksi:
#     Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0            3938             3              2        1958  3.913819
# 1            2010             2              3        2003  2.767976
# 2            1934             4              2        1973  0.847470
# 3            4170             1              3        2006  1.069368
# 4             668             2              2        1964  1.147526
# 5            3952             2              3        1999  4.621789
# 6            1089             3              1        2012  3.083953
# 7            3973             1              1        1997  2.802667
# 8            3195             2              1        2022  1.074873
# 9            3934             3              1        1957  1.469066
#
#    Garage_Size  Neighborhood_Quality
# 0            2                     4
# 1            0                     8
# 2            0                     8
# 3            0                     5
# 4            0                     9
# 5            2                     3
# 6            0                     3
# 7            1                     4
# 8            0                     2
# 9            1                     7
# Hasil prediksi:
#  [835723.54831907 468092.8592372  406273.77585272 866273.89206603
#  129015.02567753 888452.1550658  291280.3425731  831812.97644068
#  681308.36434494 784540.28139154]

# %%
dshouse.corr('pearson')
# Out:
#                       Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  \
# Square_Footage              1.000000     -0.043564      -0.031584   -0.022392
# Num_Bedrooms               -0.043564      1.000000       0.022848   -0.015820
# Num_Bathrooms              -0.031584      0.022848       1.000000   -0.021063
# Year_Built                 -0.022392     -0.015820      -0.021063    1.000000
# Lot_Size                    0.089479     -0.009355       0.034923   -0.061050
# Garage_Size                 0.030593      0.113761       0.024846   -0.025485
# Neighborhood_Quality       -0.008357     -0.049024       0.017585   -0.009549
# House_Price                 0.991261      0.014633      -0.001862    0.051967
#
#                       Lot_Size  Garage_Size  Neighborhood_Quality  House_Price
# Square_Footage        0.089479     0.030593             -0.008357     0.991261
# Num_Bedrooms         -0.009355     0.113761             -0.049024     0.014633
# Num_Bathrooms         0.034923     0.024846              0.017585    -0.001862
# Year_Built           -0.061050    -0.025485             -0.009549     0.051967
# Lot_Size              1.000000     0.002436              0.037630     0.160412
# Garage_Size           0.002436     1.000000             -0.011287     0.052133
# Neighborhood_Quality  0.037630    -0.011287              1.000000    -0.007770
# House_Price           0.160412     0.052133             -0.007770     1.000000

# %% [markdown]
# # Save Model

# %%
import pickle
filename = 'house.sav'
pickle.dump(model,open(filename,'wb'))
